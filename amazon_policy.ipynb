# %%
# @title Step 0: Install Required Libraries
# !pip install -q -U \
    langchain \
    langchain-core \
    langchain-community \
    langchain-text-splitters \
    langchain-google-genai \
    langchain-huggingface \
    sentence-transformers \
    faiss-cpu \
    tiktoken
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.5/108.5 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.2/490.2 kB 18.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 64.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 92.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.1/719.1 kB 48.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 67.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 234.9/234.9 kB 19.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.43.0, but you have google-auth 2.47.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.

# %%
# @title Step 1: Mount Drive & Verify Input Files
from google.colab import drive
import os

drive.mount('/content/drive')

OLD_POLICY_PATH = "/content/drive/MyDrive/PolicyProject/policy_v1.txt"
NEW_POLICY_PATH = "/content/drive/MyDrive/PolicyProject/policy_v2.txt"

if os.path.exists(OLD_POLICY_PATH):
    print("Old policy file located.")
else:
    print("Old policy file not found.")

if os.path.exists(NEW_POLICY_PATH):
    print("New policy file located.")
else:
    print("New policy file not found.")
# Out:
# Mounted at /content/drive
# Old policy file located.
# New policy file located.

# %%
# @title Step 2: Remove Common Sentences
import re

def load_file(path):
    with open(path, "r", encoding="utf-8") as f:
        return f.read()

def remove_common_sentences(old_text, new_text):
    def split_sentences(text):
        return re.split(r'(?<=[.!?])\s+', text)

    old_sents = split_sentences(old_text)
    new_sents = split_sentences(new_text)

    old_set = set(s.strip() for s in old_sents)
    new_set = set(s.strip() for s in new_sents)

    common = old_set.intersection(new_set)

    old_unique = [s for s in old_sents if s.strip() not in common]
    new_unique = [s for s in new_sents if s.strip() not in common]

    return " ".join(old_unique), " ".join(new_unique)

old_raw = load_file(OLD_POLICY_PATH)
new_raw = load_file(NEW_POLICY_PATH)

old_text, new_text = remove_common_sentences(old_raw, new_raw)

print("Original lengths:", len(old_raw), len(new_raw))
print("Optimized lengths:", len(old_text), len(new_text))
print(f"Reduced content by approximately: {100 - (len(new_text)/len(new_raw)*100):.0f}%")
# Out:
# Original lengths: 144833 138687
# Optimized lengths: 21910 15176
# Reduced content by approximately: 89%

# %%
# @title Step 3: Chunk Policies into Semantic Units
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=150
)

old_chunks = splitter.create_documents([old_text])
new_chunks = splitter.create_documents([new_text])

print(f"Old chunks: {len(old_chunks)}")
print(f"New chunks: {len(new_chunks)}")
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# Old chunks: 38
# New chunks: 26

# %%
# @title Step 4: Build Vector Store for Semantic Retrieval
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vector_store = FAISS.from_documents(old_chunks, embeddings)
retriever = vector_store.as_retriever(search_kwargs={"k": 1})

print("Vector store initialized")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Vector store initialized

# %%
# @title Step 5: Cosine Similarity Scoring
import numpy as np

def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

def compute_similarity(text1, text2, embedding_model):
    v1 = embedding_model.embed_query(text1)
    v2 = embedding_model.embed_query(text2)
    sim = cosine_similarity(v1, v2)
    return float(sim)

# %%
# @title Step 6: Semantic Change Index
def semantic_change_index(similarity: float) -> str:
    if similarity >= 0.95:
        return "NO_SEMANTIC_CHANGE"
    elif similarity >= 0.75:
        return "CLARIFICATION_NEEDED"
    else:
        return "LLM_CHECK"

def confidence_score(semantic_index: str):
    scores = {
        "NO_SEMANTIC_CHANGE": 0.95,
        "CLARIFICATION_NEEDED": 0.75
    }
    return scores.get(semantic_index, 0.6)

# %%
# @title Step 7: Semantic Alignment
def align_documents(new_docs, retriever, embeddings):
    aligned = []

    for doc in new_docs:
        match = retriever.invoke(doc.page_content)
        if not match:
            continue

        old_doc = match[0]
        sim = compute_similarity(doc.page_content, old_doc.page_content, embeddings)

        aligned.append({
            "new_content": doc.page_content,
            "old_content": old_doc.page_content,
            "similarity": round(sim, 3),
            "semantic_index": semantic_change_index(sim)
        })

    return aligned

aligned_pairs = align_documents(new_chunks, retriever, embeddings)
print(f"Aligned pairs: {len(aligned_pairs)}")
# Out:
# Aligned pairs: 26

# %%
# @title Step 8: LLM Setup
import os
import time
from typing import Literal
from pydantic import BaseModel, Field

from google.colab import userdata
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate

os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")

class ChangeAnalysis(BaseModel):
    change_detected: bool
    classification: Literal[
        "BREAKING",
        "NON_BREAKING",
        "CLARIFICATION",
        "NEW_FEATURE",
        "NO_CHANGE"
    ]
    confidence: float
    reasoning: str

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

structured_llm = llm.with_structured_output(ChangeAnalysis)

prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        "You are a Senior Regulatory Compliance Analyst AI. "
        "You will only be asked to analyze policy sections where a semantic change "
        "has already been detected by an upstream machine learning system. "
        "Do NOT classify changes as NO_CHANGE or CLARIFICATION."
    ),
    (
        "human",
        """
Two versions of a policy section are shown below.
A semantic change is already confirmed.

OLD VERSION:
{old_text}

NEW VERSION:
{new_text}

Your task:

1. Analyze how the change affects user or developer behavior.
2. Classify the change into exactly ONE of the following categories:

- NON_BREAKING:
  The change modifies or adds constraints but does NOT require users to change
  existing behavior to remain compliant.

- BREAKING:
  The change introduces new restrictions, removes permissions, or requires
  users to change behavior to remain compliant.

- NEW_FEATURE:
  The change introduces an entirely new rule, requirement, or capability that
  did not exist previously.

3. Provide a confidence score between 0.0 and 1.0.
   - High confidence (≥0.8): impact is clear and unambiguous.
   - Medium confidence (0.6–0.79): some interpretation required.
   - Low confidence (<0.6): borderline or ambiguous impact.

Respond strictly using the structured output schema provided.
"""
    )
])

# %%
# @title Step 9: Token Throttling
class TokenThrottle:
    def __init__(self, tokens_per_minute=180_000):
        self.tokens_per_minute = tokens_per_minute
        self.used = 0
        self.start = time.time()

    def consume(self, tokens):
        now = time.time()
        if now - self.start > 60:
            self.used = 0
            self.start = now

        if self.used + tokens > self.tokens_per_minute:
            time.sleep(60 - (now - self.start))
            self.used = 0
            self.start = time.time()

        self.used += tokens

# %%
# @title Step 10: Hybrid Execution
def analyze_impact(aligned_pairs):
    results = []
    for i, pair in enumerate(aligned_pairs):
        try:
            sim = pair["similarity"]
            s_index = pair["semantic_index"]

            print(f"\n--- Pair {i+1} ---")
            print(f"Similarity Score   : {sim}")
            print(f"Semantic Index     : {s_index}")

            # Rule-based decisions

            if s_index == "NO_SEMANTIC_CHANGE":
                classification = "NO_CHANGE"
                reasoning = "High semantic similarity; no meaningful change detected."
                confidence = confidence_score(s_index)

                print("Decision Path      : RULE-BASED")
                print("Classification     : NO_CHANGE")

            elif s_index == "CLARIFICATION_NEEDED":
                classification = "CLARIFICATION"
                reasoning = "Moderate similarity; wording clarified without intent change."
                confidence = confidence_score(s_index)

                print("Decision Path      : RULE-BASED")
                print("Classification     : CLARIFICATION")

            # LLM-based decision
            else:
                print("Decision Path      : LLM-BASED")
                print("LLM Status         : Invoked")

                # LLM Call
                parsed = (prompt | structured_llm).invoke({
                    "old_text": pair["old_content"],
                    "new_text": pair["new_content"]
                })

                classification = parsed.classification
                reasoning = parsed.reasoning   # LLM output
                confidence = parsed.confidence

                print("Classification     :", classification)
                print("LLM Reasoning      :", reasoning)
                print(f"LLM Confidence     : {confidence:.2f}")

            results.append({
                "pair_id": i,
                "classification": classification,
                "semantic_index": s_index,
                "similarity": sim,
                "confidence": round(confidence, 2),
                "reasoning": reasoning
            })

        except Exception as e:
            if "429" in str(e):
                print("\n RATE LIMIT HIT (429)")
                print(f"Execution stopped at pair {i+1}")
                print(f"Pairs processed safely: {len(results)}")
                break
            else:
                print(f"Error at pair {i+1}: {e}")
                continue
    return results

final_report = analyze_impact(aligned_pairs)
# Out:
# --- Pair 1 ---
# Similarity Score   : 1.0
# Semantic Index     : NO_SEMANTIC_CHANGE
# Decision Path      : RULE-BASED
# Classification     : NO_CHANGE
#
# --- Pair 2 ---
# Similarity Score   : 0.992
# Semantic Index     : NO_SEMANTIC_CHANGE
# Decision Path      : RULE-BASED
# Classification     : NO_CHANGE
#
# --- Pair 3 ---
# Similarity Score   : 0.751
# Semantic Index     : CLARIFICATION_NEEDED
# Decision Path      : RULE-BASED
# Classification     : CLARIFICATION
#
# --- Pair 4 ---
# Similarity Score   : 0.727
# Semantic Index     : LLM_CHECK
# Decision Path      : LLM-BASED
# LLM Status         : Invoked
# Classification     : BREAKING
# LLM Reasoning      : The definition of an 'App' has been expanded from 'Mobile App' to 'Mobile/TV App', explicitly including 'Vega OS' and 'television operating system'. This change means that applications designed for television operating systems and Vega OS are now explicitly subject to the terms and conditions previously applied only to 'Mobile Apps'. This introduces new restrictions and compliance requirements for developers of TV apps and Vega OS apps, as these apps are now explicitly covered by the policy's governing law, jurisdiction, and potentially other referenced addendums (like the GDPR DPA mentioned just before the excerpt). This requires developers of such apps to ensure their compliance with these terms, which might be a change from their previous understanding or operational procedures. The clarification of the jurisdiction scope also makes the application of the governing law more explicit and potentially broader.
# LLM Confidence     : 0.90
#
# --- Pair 5 ---
# Similarity Score   : 0.713
# Semantic Index     : LLM_CHECK
# Decision Path      : LLM-BASED
# LLM Status         : Invoked
# Classification     : BREAKING
# LLM Reasoning      : The old policy explicitly listed specific royalty percentages for various app types (e.g., 70% for Mobile Apps, 80% for Movies & TV). The new policy removes these explicit percentages entirely from this section, replacing them with a general statement about royalty calculation and a reference to Section 5 for definitions and calculation details. This change removes direct and specific information about royalty rates that was previously available in this section. Developers can no longer ascertain their royalty rates from this section and are now required to consult another section for calculation details, which could imply a change in the underlying royalty structure or calculation method. This fundamentally alters how developers access and understand their earnings information, thus requiring a change in their information-seeking behavior and potentially impacting their expected earnings.
# LLM Confidence     : 0.85
#
# --- Pair 6 ---
# Similarity Score   : 0.405
# Semantic Index     : LLM_CHECK
# Decision Path      : LLM-BASED
# LLM Status         : Invoked
# Classification     : BREAKING
# LLM Reasoning      : The new version completely removes all specific royalty rates and app type classifications that were present in the old version. Developers previously relied on this section to understand the financial terms and royalty percentages for various app types (e.g., Mobile Apps, Subscription In-App Products, Amazon Underground Apps, Alexa Skills, PC Games). The removal of this information means developers can no longer determine their royalty rates from this policy section, fundamentally altering the financial framework and requiring them to seek this critical information elsewhere or operate under new, undefined terms. This constitutes a breaking change as it removes previously defined permissions and financial expectations.
# LLM Confidence     : 0.95
#
# --- Pair 7 ---
# Similarity Score   : 0.896
# Semantic Index     : CLARIFICATION_NEEDED
# Decision Path      : RULE-BASED
# Classification     : CLARIFICATION
#
# --- Pair 8 ---
# Similarity Score   : 0.802
# Semantic Index     : CLARIFICATION_NEEDED
# Decision Path      : RULE-BASED
# Classification     : CLARIFICATION
#
# --- Pair 9 ---
# Similarity Score   : 0.85
# Semantic Index     : CLARIFICATION_NEEDED
# Decision Path      : RULE-BASED
# Classification     : CLARIFICATION
#
# --- Pair 10 ---
# Similarity Score   : 0.791
# Semantic Index     : CLARIFICATION_NEEDED
# Decision Path      : RULE-BASED
# Classification     : CLARIFICATION
#
# --- Pair 11 ---
# Similarity Score   : 0.799
# Semantic Index     : CLARIFICATION_NEEDED
# Decision Path      : RULE-BASED
# Classification     : CLARIFICATION
#
# --- Pair 12 ---
# Similarity Score   : 0.803
# Semantic Index     : CLARIFICATION_NEEDED
# Decision Path      : RULE-BASED
# Classification     : CLARIFICATION
#
# --- Pair 13 ---
# Similarity Score   : 0.858
# Semantic Index     : CLARIFICATION_NEEDED
# Decision Path      : RULE-BASED
# Classification     : CLARIFICATION
#
# --- Pair 14 ---
# Similarity Score   : 0.819
# Semantic Index     : CLARIFICATION_NEEDED
# Decision Path      : RULE-BASED
# Classification     : CLARIFICATION
#
# --- Pair 15 ---
# Similarity Score   : 0.85
# Semantic Index     : CLARIFICATION_NEEDED
# Decision Path      : RULE-BASED
# Classification     : CLARIFICATION
#
# --- Pair 16 ---
# Similarity Score   : 0.793
# Semantic Index     : CLARIFICATION_NEEDED
# Decision Path      : RULE-BASED
# Classification     : CLARIFICATION
#
# --- Pair 17 ---
# Similarity Score   : 0.94
# Semantic Index     : CLARIFICATION_NEEDED
# Decision Path      : RULE-BASED
# Classification     : CLARIFICATION
#
# --- Pair 18 ---
# Similarity Score   : 0.721
# Semantic Index     : LLM_CHECK
# Decision Path      : LLM-BASED
# LLM Status         : Invoked
# Classification     : BREAKING
# LLM Reasoning      : The policy's scope for 'SBAP Sales' has been expanded from 'Mobile Apps' to 'Mobile/TV Apps'. This means that sales of TV applications and their in-app products are now explicitly included in the definition of 'SBAP Sales'. Developers with TV applications, or those who previously did not consider their TV applications under the 'Mobile Apps' definition, will now need to ensure compliance with the 'SBAP Sales' definition and any associated policies for their TV apps. This introduces new restrictions and compliance requirements for TV app developers, requiring them to change their understanding of scope and potentially their behavior to remain compliant. Additionally, the specific clause regarding GDPR applicability to ACK Metrics transmitted to the ACK Analytics Service has been removed, which removes a specific restriction. However, the expansion of scope to 'Mobile/TV Apps' is a more significant change in terms of introducing new compliance obligations for a broader category of products.
# LLM Confidence     : 0.90
#
# --- Pair 19 ---
# Similarity Score   : 0.948
# Semantic Index     : CLARIFICATION_NEEDED
# Decision Path      : RULE-BASED
# Classification     : CLARIFICATION
#
# --- Pair 20 ---
# Similarity Score   : 0.813
# Semantic Index     : CLARIFICATION_NEEDED
# Decision Path      : RULE-BASED
# Classification     : CLARIFICATION
#
# --- Pair 21 ---
# Similarity Score   : 0.829
# Semantic Index     : CLARIFICATION_NEEDED
# Decision Path      : RULE-BASED
# Classification     : CLARIFICATION
#
# --- Pair 22 ---
# Similarity Score   : 0.607
# Semantic Index     : LLM_CHECK
# Decision Path      : LLM-BASED
# LLM Status         : Invoked
# Classification     : NEW_FEATURE
# LLM Reasoning      : The new policy section introduces an entirely new program called the 'Cloud App Program' (CAP) for Mobile/TV Apps on Fire TV devices. This includes new definitions ('Cloud App Program', 'Cloud App'), new functionality (running apps in Amazon's cloud for expanded device compatibility, enabling Fire OS Apps on Vega OS), new eligibility criteria, and new associated 'CAP Fees'. This represents a new capability and set of rules that did not exist in the previous policy section, which focused on testers, list prices, and royalty payments.
# LLM Confidence     : 0.95
#
# --- Pair 23 ---
# Similarity Score   : 0.604
# Semantic Index     : LLM_CHECK
# Decision Path      : LLM-BASED
# LLM Status         : Invoked
# Classification     : NEW_FEATURE
# LLM Reasoning      : The new policy section introduces the 'Cloud App Program' (CAP) and associated 'CAP Fees' that developers must pay to Amazon. This represents an entirely new financial obligation and set of payment terms (within 30 days of invoice, potential electronic payment, and tax responsibilities) that did not exist in the previous policy section, which focused on royalties paid *to* developers. This is not a modification of existing terms but the introduction of a new program with new requirements.
# LLM Confidence     : 0.90
#
# --- Pair 24 ---
# Similarity Score   : 0.53
# Semantic Index     : LLM_CHECK
# Decision Path      : LLM-BASED
# LLM Status         : Invoked
# Classification     : NEW_FEATURE
# LLM Reasoning      : The new policy section introduces entirely new requirements and obligations related to Indirect Taxes and withholding taxes. This includes providing information to Amazon for tax determination, furnishing exemption certificates, and ensuring payments are made free and clear of withholding or deduction for taxes, with the user responsible for paying additional amounts if withholding taxes are required. These concepts and responsibilities were not present in the old policy section, which focused on Per-Minute Rates and Underground Royalties. This constitutes a new set of rules and capabilities rather than a modification of existing ones.
# LLM Confidence     : 0.95
#
# --- Pair 25 ---
# Similarity Score   : 0.615
# Semantic Index     : LLM_CHECK
# Decision Path      : LLM-BASED
# LLM Status         : Invoked
# Classification     : BREAKING
# LLM Reasoning      : The old policy section detailed the 'Amazon Underground' program for Mobile Apps. The new policy section completely removes any mention of 'Amazon Underground' and its associated terms. This implies the discontinuation or removal of the 'Amazon Underground' program's terms from this section, which is a breaking change for developers who participated in or relied on that program. Furthermore, the new section introduces entirely new obligations regarding tax withholding for payments and grants of rights for 'Cloud Apps', which are new requirements that developers must comply with.
# LLM Confidence     : 0.90
#
# --- Pair 26 ---
# Similarity Score   : 0.567
# Semantic Index     : LLM_CHECK
# Decision Path      : LLM-BASED
# LLM Status         : Invoked
# Classification     : NEW_FEATURE
# LLM Reasoning      : The old policy section discusses requirements for 'Mobile Apps' and 'Subscription In-App Products', including delivery of content and payment methods. The new policy section introduces an entirely new concept: 'Cloud Apps' and their distribution through a 'Cloud App Program' (CAP). It outlines the terms for distributing Cloud Apps, removing them from availability, and how CAP fees are handled. This is not a modification of existing rules but rather the introduction of a new set of rules for a distinct product category and distribution mechanism that did not exist in the previous context.
# LLM Confidence     : 0.95

# %%
# @title Step 11: Summary Metrics
from collections import Counter

def summarize(results):
    return {
        "total_pairs": len(results),
        "distribution": dict(Counter(r["classification"] for r in results)),
        "avg_confidence": round(
            sum(r["confidence"] for r in results) / len(results), 2
        )
    }

summary = summarize(final_report)

print("Analysis Summary")
print(f"Total Aligned Pairs: {summary['total_pairs']}")
print("Change Distribution:")
for classification, count in summary['distribution'].items():
    print(f"  - {classification}: {count}")
print(f"Average Confidence Score: {summary['avg_confidence']:.2f}")
# Out:
# Analysis Summary
# Total Aligned Pairs: 26
# Change Distribution:
#   - NO_CHANGE: 2
#   - CLARIFICATION: 15
#   - BREAKING: 5
#   - NEW_FEATURE: 4
# Average Confidence Score: 0.82

# %%
# @title Step 12: Result Analysis
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(final_report)
df.head()


plt.figure()
plt.hist(df["similarity"], bins=20)
plt.xlabel("Cosine Similarity")
plt.ylabel("Number of Policy Pairs")
plt.title("Distribution of Semantic Similarity Scores")
plt.show()

# %%
# @title Step 13: Semantic Change Index Distribution
index_counts = df["semantic_index"].value_counts()

plt.figure()
index_counts.plot(kind="bar")
plt.xlabel("Semantic Index")
plt.ylabel("Count")
plt.title("Semantic Change Severity Distribution")
plt.show()

# %%
# @title Step 14: Rule-Based vs LLM Decision Split
df["decision_path"] = df["semantic_index"].apply(
    lambda x: "LLM" if x == "LLM_CHECK" else "RULE"
)

path_counts = df["decision_path"].value_counts()

plt.figure()
path_counts.plot(kind="bar")
plt.xlabel("Decision Path")
plt.ylabel("Count")
plt.title("Rule-Based vs LLM Decisions")
plt.show()

plt.figure()
plt.scatter(df["similarity"], df["confidence"])
plt.xlabel("Similarity Score")
plt.ylabel("Confidence")
plt.title("Confidence vs Semantic Similarity")
plt.show()

# %%
# @title Step 15: Final Quantitative Summary
finalSummary = {
    "Total Pairs Processed": len(df),
    "LLM Usage (%)": float(round(
        (df["decision_path"] == "LLM").mean() * 100, 2
    )),
    "Average Similarity": float(round(df["similarity"].mean(), 3)),
    "Average Confidence": float(round(df["confidence"].mean(), 3))
}
finalSummary
# Out:
# {'Total Pairs Processed': 26,
#  'LLM Usage (%)': 34.62,
#  'Average Similarity': 0.77,
#  'Average Confidence': 0.823}
